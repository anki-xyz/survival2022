# %%
import h5py 
import matplotlib.pyplot as plt
# %matplotlib qt

# %%
fp = h5py.File(r"fancy_file.hdf5")

# %%
single_molecules = fp['locs'][:500]

# %%
# Show single molecules in (x,y)
for i in single_molecules:
    plt.scatter(i[1], i[2])
